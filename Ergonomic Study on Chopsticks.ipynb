# %%
import numpy as np 
import pandas as pd # linear algebra
import seaborn as sns # data processing, CSV file I/O (e.g. pd.read_csv)

import os
print(os.listdir('C:/Users/SAMSUNG/Desktop/example'))
# Out:
# ['BreadBasket_DMS.csv', 'chopstick-effectiveness.csv']

# %%
data = pd.read_csv("C:/Users/SAMSUNG/Desktop/example/chopstick-effectiveness.csv")

# %%
data.head()
# Out:
#    Food.Pinching.Efficiency  Individual  Chopstick.Length
# 0                     19.55           1               180
# 1                     27.24           2               180
# 2                     28.76           3               180
# 3                     31.19           4               180
# 4                     21.91           5               180

# %%
sns.pairplot(data)

# %%
necessary_features =['Food.Pinching.Efficiency','Individual']
X = data[necessary_features]
Y = data[['Chopstick.Length']]

print(Y.head())
# Out:
#    Chopstick.Length
# 0               180
# 1               180
# 2               180
# 3               180
# 4               180

# %%
from sklearn.model_selection import train_test_split

train_X, test_X, train_Y, test_Y = train_test_split(X,Y, test_size = 0.33)
print(len(train_Y))
# Out:
# 124

# %%
# Learn algorithm
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error

def choose_better_model(amount_leafes):
    model = DecisionTreeRegressor(max_depth=amount_leafes)
    model.fit(train_X, train_Y)
    predicted_value = model.predict(test_X)
    return model, mean_absolute_error(predicted_value, test_Y)

best_score = 0
for i in [1, 2, 3, 4, 5]:
    model, score = choose_better_model(i)
    print(score)
    if score > best_score:
        final_model = model
        best_score = score
# Out:
# 50.55107526881719
# 51.27143831412399
# 53.23478020240353
# 57.16951652499868
# 61.88919145370758
